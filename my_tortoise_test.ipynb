# %%
# !git clone https://github.com/jhowilbur/tortoise-tts.git

# %% [markdown]
# # With GPU

# %%
# %cd /content/tortoise-tts

# !pip install -U scipy
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install -r requirements.txt

# %% [markdown]
# # Without CPU

# %%
# !git clone https://github.com/jhowilbur/tortoise-tts.git
# %cd /content/tortoise-tts

# !pip install -U scipy
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install -r requirements.txt

# %%
# %cd /content/tortoise-tts

# !python tortoise/do_tts.py --text "I'm going to speak this but its not me you know" --voice=wilbur --preset fast

# %%
# %cd /content/tortoise-tts

# !python tortoise/do_tts.py --text "I'm going to speak this but its not me you know, it's just a test, Mas agora eu posso mudar o idioma facilmente, Pouvez-vous comprendre à quel point c’est puissant ? 今では日本語も話せるようになりました" --voice=wilbur

# %%
# %cd /content/tortoise-tts

# !python tortoise/read.py --textfile poem.txt  --voice=w
